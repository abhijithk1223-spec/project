# %%
f = open("file.txt","rt")
print(f.readline())
f.readline()
print(f.readline())
f.close()
# Out:
# hello world 1
#
# hello world 3

# %%
f = open("write.txt","wt")
f.write("this is a write file")
# Out:
# 20

# %%
f = open("write.txt","at")
f.write("this is a appended text")
f.close()
f = open("write.txt","rt")
print(f.read())
f.close()
# Out:
# this is a written textthis is a appended textthis is a appended textthis is a appended textthis is a appended textthis is a appended textthis is a appended text

# %%
f = open("file4.txt","x")

# %%
import os
os.remove("write.txt")
